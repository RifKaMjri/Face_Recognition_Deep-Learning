# %%
# !pip install face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.2MB 42kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566172 sha256=c5aa421477c67b8f3e205751d81936e1e05e0767361e5970758d3ab82137c3ef
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
from PIL import Image
from matplotlib import pyplot as plt
import numpy as np
import face_recognition
import keras
from keras.models import load_model
import cv2
# Out:
# Using TensorFlow backend.

# %%
image1 = Image.open("/content/drive/My Drive/face detection/Esperance-Chaâlali-ben-mohamed.jpg")
image_array1 = np.array(image1)
plt.imshow(image_array1)

# %%
image = face_recognition.load_image_file("/content/drive/My Drive/face detection/Esperance-Chaâlali-ben-mohamed.jpg")

face_locations = face_recognition.face_locations(image)

# %%
face_locations
# Out:
# [(106, 161, 142, 125),
#  (126, 433, 162, 397),
#  (58, 101, 94, 65),
#  (54, 509, 90, 473),
#  (106, 341, 142, 305),
#  (126, 497, 162, 461),
#  (50, 193, 86, 157)]

# %%
face_image  = cv2.imread("/content/drive/My Drive/face detection/Esperance-Chaâlali-ben-mohamed.jpg")
plt.imshow(face_image)

# %%
image = face_recognition.load_image_file("/content/drive/My Drive/face detection/Esperance-Chaâlali-ben-mohamed.jpg")
face_locations = face_recognition.face_locations(face_image)
top, right, bottom, left = face_locations[0]
face_image = face_image[top:bottom, left:right]
plt.imshow(face_image)

# %%
face_image = cv2.resize(face_image, (48,48))
face_image = cv2.cvtColor(face_image, cv2.COLOR_BGR2GRAY)
face_image = np.reshape(face_image, [1, face_image.shape[0], face_image.shape[1], 1])

# %%
from tensorflow.keras.models import load_model
from keras.layers import Dense , Activation


model = load_model('/content/drive/My Drive/emotion/model_emotion1.h5')

# %%
face_image.shape
# Out:
# (1, 48, 48, 1)

# %%
predicted_class = np.argmax(model.predict(face_image))

# %%
emotion_dict= {'Angry': 0, 'Sad': 5, 'Neutral': 4, 'Disgust': 1, 'Surprise': 6, 'Fear': 2, 'Happy': 3}

# %%
label_map = dict((v,k) for k,v in emotion_dict.items()) 
predicted_label = label_map[predicted_class]

# %%
print(predicted_label)
# Out:
# Sad
